# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva-tech2004/Atharva/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/DATASETS/water-potability.csv')

# %%
df = pd.read_csv(source_folder)

# %%
df
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0           NaN  204.890455  20791.318981     7.300212  368.516441
# 1      3.716080  129.422921  18630.057858     6.635246         NaN
# 2      8.099124  224.236259  19909.541732     9.275884         NaN
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# ...         ...         ...           ...          ...         ...
# 16271       NaN  181.210510  30280.788593    10.382547  256.630068
# 16272  6.912608  155.740495  17973.178859     4.916303  275.908228
# 16273  8.860324  233.625145  19550.299680     6.519063         NaN
# 16274  7.480728  117.057314  28357.942774     4.702821  414.855784
# 16275  2.974429  147.148675  17326.202253     2.498597  393.168745
#
#        Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0        564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # New Section

# %%
df.shape
# Out:
# (16276, 10)

# %%
df.size
# Out:
# 162760

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16276 entries, 0 to 16275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               13839 non-null  float64
#  1   Hardness         16276 non-null  float64
#  2   Solids           16276 non-null  float64
#  3   Chloramines      16276 non-null  float64
#  4   Sulfate          12478 non-null  float64
#  5   Conductivity     16276 non-null  float64
#  6   Organic_carbon   16276 non-null  float64
#  7   Trihalomethanes  15440 non-null  float64
#  8   Turbidity        16276 non-null  float64
#  9   Potability       16276 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#                  ph      Hardness        Solids   Chloramines       Sulfate  \
# count  13839.000000  16276.000000  16276.000000  16276.000000  12478.000000
# mean       7.078044    196.831230  22101.146015      7.094644    333.512413
# std        1.591133     32.829265   8903.779491      1.571294     41.754302
# min        0.000000     47.432000    320.942611      0.352000    129.000000
# 25%        6.087306    177.174021  15547.186626      6.084133    306.725885
# 50%        7.038092    197.439216  21051.365376      7.087189    333.198191
# 75%        8.043889    217.368014  27420.167425      8.097302    359.951766
# max       14.000000    323.124000  61227.196008     13.127000    481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes     Turbidity  \
# count  16276.000000    16276.000000     15440.000000  16276.000000
# mean     425.424982       14.293217        66.482820      3.970952
# std       79.729171        3.323172        16.016172      0.780541
# ...

# %%
df.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
display(df.head())
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
display(df.tail())
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 16271       NaN  181.210510  30280.788593    10.382547  256.630068
# 16272  6.912608  155.740495  17973.178859     4.916303  275.908228
# 16273  8.860324  233.625145  19550.299680     6.519063         NaN
# 16274  7.480728  117.057314  28357.942774     4.702821  414.855784
# 16275  2.974429  147.148675  17326.202253     2.498597  393.168745
#
#        Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 16271    487.997262       11.346302        68.843866   3.779554           1
# 16272    439.648051       18.380712        55.507468   2.612249           0
# 16273    285.412436       13.093262        25.061904   2.476674           0
# 16274    472.059339       18.340212        76.344581   3.714875           0
# 16275    375.411470       12.798187        76.413069   2.779902           1

# %%
df.count()
# Out:
# ph                 13839
# Hardness           16276
# Solids             16276
# Chloramines        16276
# Sulfate            12478
# Conductivity       16276
# Organic_carbon     16276
# Trihalomethanes    15440
# Turbidity          16276
# Potability         16276
# dtype: int64

# %%
df.isnull()
# Out:
#           ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  \
# 0       True     False   False        False    False         False
# 1      False     False   False        False     True         False
# 2      False     False   False        False     True         False
# 3      False     False   False        False    False         False
# 4      False     False   False        False    False         False
# ...      ...       ...     ...          ...      ...           ...
# 16271   True     False   False        False    False         False
# 16272  False     False   False        False    False         False
# 16273  False     False   False        False     True         False
# 16274  False     False   False        False    False         False
# 16275  False     False   False        False    False         False
#
#        Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0               False            False      False       False
# ...

# %%
df.isnull().sum()
# Out:
# ph                 2437
# Hardness              0
# Solids                0
# Chloramines           0
# Sulfate            3798
# Conductivity          0
# Organic_carbon        0
# Trihalomethanes     836
# Turbidity             0
# Potability            0
# dtype: int64

# %%
df.notnull()
# Out:
#           ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  \
# 0      False      True    True         True     True          True
# 1       True      True    True         True    False          True
# 2       True      True    True         True    False          True
# 3       True      True    True         True     True          True
# 4       True      True    True         True     True          True
# ...      ...       ...     ...          ...      ...           ...
# 16271  False      True    True         True     True          True
# 16272   True      True    True         True     True          True
# 16273   True      True    True         True    False          True
# 16274   True      True    True         True     True          True
# 16275   True      True    True         True     True          True
#
#        Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0                True             True       True        True
# ...

# %%
df.notnull().sum()
# Out:
# ph                 13839
# Hardness           16276
# Solids             16276
# Chloramines        16276
# Sulfate            12478
# Conductivity       16276
# Organic_carbon     16276
# Trihalomethanes    15440
# Turbidity          16276
# Potability         16276
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df["Potability"].value_counts()
# Out:
# Potability
# 0    9901
# 1    6375
# Name: count, dtype: int64

# %%
print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
def remove_outliers(df):
    for column in df.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df[column], 25, method='midpoint')
        Q3 = np.percentile(df[column], 75, method='midpoint')
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# %%
df_1 = remove_outliers(df)

# %%
df_1
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0      7.078044  204.890455  20791.318981     7.300212  368.516441
# 2      8.099124  224.236259  19909.541732     9.275884  333.512413
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# ...         ...         ...           ...          ...         ...
# 16265  5.280292  164.057389  13679.056905     5.971385  333.512413
# 16266  6.768060  179.805992  23793.031358     5.332099  333.198191
# 16268  6.728004  201.126896  22888.788065     7.663988  319.463491
# 16269  8.719240  181.013100  17430.919720     7.421210  333.512413
# 16272  6.912608  155.740495  17973.178859     4.916303  275.908228
#
#        Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0        564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["ph"], bins=30, kde=True)
plt.title("ph Distribution")
plt.xlabel("ph")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Potability', data=df, palette='coolwarm')
plt.title('Distribution of Potable vs Non-Potable Water')
plt.show()
# Out:
# /tmp/ipykernel_362/2982343102.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Potability', data=df, palette='coolwarm')

# %%
from sklearn.model_selection import train_test_split , GridSearchCV

# %%
X = df.drop(columns=["Potability"])
y = df["Potability"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
features = df.drop(columns=["Potability"])
df_normalized = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
df_normalized["Potability"] = df["Potability"].values

# %%
scaler
# Out:
# MinMaxScaler()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dt = DecisionTreeClassifier()
dt
# Out:
# DecisionTreeClassifier()

# %%
dt = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=8,
    random_state=42
)

dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
def evaluate_model(y_test, y_pred, model_name):
    print(f"\nModel: {model_name}")
def evaluate_model(y_test, y_pred, model_name):
    print(f"\nModel: {model_name}")
    print("Accuracy:", round(accuracy_score(y_test, y_pred) * 100, 2), "%")
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))

# %%
evaluate_model(y_test, y_pred_dt, "Tuned Decision Tree")
# Out:
# Model: Tuned Decision Tree
# Accuracy: 66.65 %
# Confusion Matrix:
#  [[1831  157]
#  [ 929  339]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.92      0.77      1988
#            1       0.68      0.27      0.38      1268
#
#     accuracy                           0.67      3256
#    macro avg       0.67      0.59      0.58      3256
# weighted avg       0.67      0.67      0.62      3256

# %%
dt_params = {'max_depth': [5, 10, 15], 'min_samples_split': [2, 5, 10], 'criterion': ['gini', 'entropy']}
dt_grid = GridSearchCV(DecisionTreeClassifier(), dt_params, cv=5)
dt_grid.fit(X_train, y_train)
y_pred_dt = dt_grid.predict(X_test)
evaluate_model(y_test, y_pred_dt, "GridSearchCV Decision Tree")
# Out:
# Model: GridSearchCV Decision Tree
# Accuracy: 85.69 %
# Confusion Matrix:
#  [[1943   45]
#  [ 421  847]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1988
#            1       0.95      0.67      0.78      1268
#
#     accuracy                           0.86      3256
#    macro avg       0.89      0.82      0.84      3256
# weighted avg       0.87      0.86      0.85      3256

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))

plot_tree(dt, filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))
plot_tree(dt, filled=True,fontsize=5)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt='d', cmap="Greens")
plt.title("Confusion Matrix - Decision Tree")
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(120.72222222222221, 0.5, 'Actual')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_lr = lr.predict(X_test)
y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
evaluate_model(y_test, y_pred_lr, "Logistic Regression")
# Out:
# Model: Logistic Regression
# Accuracy: 61.39 %
# Confusion Matrix:
#  [[1988    0]
#  [1257   11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76      1988
#            1       1.00      0.01      0.02      1268
#
#     accuracy                           0.61      3256
#    macro avg       0.81      0.50      0.39      3256
# weighted avg       0.76      0.61      0.47      3256

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
y_pred_nb = gnb.fit(X_train, y_train).predict(X_test)

# %%
gnb
# Out:
# GaussianNB()

# %%
evaluate_model(y_test, y_pred_nb, "Naïve Bayes")
# Out:
# Model: Naïve Bayes
# Accuracy: 63.02 %
# Confusion Matrix:
#  [[1773  215]
#  [ 989  279]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.89      0.75      1988
#            1       0.56      0.22      0.32      1268
#
#     accuracy                           0.63      3256
#    macro avg       0.60      0.56      0.53      3256
# weighted avg       0.61      0.63      0.58      3256

# %%
classes, counts = np.unique(y_pred_nb, return_counts=True)

# Create Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=classes, autopct="%1.1f%%", colors=['blue','red'])
plt.title("Naïve Bayes Prediction Distribution")
plt.show()

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# %%
svm
# Out:
# SVC()

# %%
evaluate_model(y_test, y_pred_svm, "Support Vector Machine")
# Out:
# Model: Support Vector Machine
# Accuracy: 61.21 %
# Confusion Matrix:
#  [[1986    2]
#  [1261    7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76      1988
#            1       0.78      0.01      0.01      1268
#
#     accuracy                           0.61      3256
#    macro avg       0.69      0.50      0.38      3256
# weighted avg       0.68      0.61      0.47      3256

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=50,
    max_depth=6,
    min_samples_split=10,
    min_samples_leaf=8,
    random_state=42
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
rf
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, min_samples_split=10,
#                        n_estimators=50, random_state=42)

# %%
evaluate_model(y_test, y_pred_rf, "Random Forest")
# Out:
# Model: Random Forest
# Accuracy: 68.83 %
# Confusion Matrix:
#  [[1980    8]
#  [1007  261]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80      1988
#            1       0.97      0.21      0.34      1268
#
#     accuracy                           0.69      3256
#    macro avg       0.82      0.60      0.57      3256
# weighted avg       0.78      0.69      0.62      3256

# %%
rf_params = {'n_estimators': [100, 150], 'max_depth': [10, 12], 'min_samples_split': [2, 4]}
rf_grid = GridSearchCV(RandomForestClassifier(), rf_params, cv=5)
rf_grid.fit(X_train, y_train)
y_pred_rf = rf_grid.predict(X_test)
evaluate_model(y_test, y_pred_rf, "GridSearchCV Random Forest")
# Out:
# Model: GridSearchCV Random Forest
# Accuracy: 84.31 %
# Confusion Matrix:
#  [[1988    0]
#  [ 511  757]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1988
#            1       1.00      0.60      0.75      1268
#
#     accuracy                           0.84      3256
#    macro avg       0.90      0.80      0.82      3256
# weighted avg       0.88      0.84      0.83      3256

# %%
importances = rf.feature_importances_
features = X.columns
sns.barplot(x=importances, y=features)
plt.title("Feature Importances (Random Forest)")
# Out:
# Text(0.5, 1.0, 'Feature Importances (Random Forest)')

# %%
plt.subplot(1,2,2)
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='d', cmap="Oranges")
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_auc_score, roc_curve , auc

# %%
svm = SVC(probability=True)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# %%
y_score_lr = lr.predict_proba(X_test)[:, 1]
y_score_nb = gnb.predict_proba(X_test)[:, 1]
y_score_dt = dt.predict_proba(X_test)[:, 1]
y_score_rf = rf.predict_proba(X_test)[:, 1]
y_score_svm = svm.predict_proba(X_test)[:, 1]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score_lr)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot(fpr, tpr, label="Logistic Regression")

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score_dt)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot(fpr, tpr, label="Decision Tree")

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score_nb)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot(fpr, tpr, label="Naïve Bayes")

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score_rf)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot(fpr, tpr, label="Random Forest")

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score_svm)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.plot(fpr, tpr, label="Support Vector Machine")

# %%
roc_auc=auc(fpr,tpr)

# %%
plt.figure()
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %%
result = pd.DataFrame({
    'Alogorithms': ['Decision Tree', 'Random Forest', 'Logistic Regression', 'Naïve Bayes', 'Support Vector Machine'],
    'Score': [accuracy_score(y_test, y_pred_dt),
              accuracy_score(y_test, y_pred_rf),
              accuracy_score(y_test, y_pred_lr),
              accuracy_score(y_test, y_pred_nb),
              accuracy_score(y_test, y_pred_svm)]
})

print(result)
# Out:
#               Alogorithms     Score
# 0           Decision Tree  0.856880
# 1           Random Forest  0.843059
# 2     Logistic Regression  0.613943
# 3             Naïve Bayes  0.630221
# 4  Support Vector Machine  0.612101

# %%
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt


models = ["Logistic Regression", "GaussianNB", "Decision Tree", "Random Forest", "Support Vector Machine"]


accuracies = [
    accuracy_score(y_test, y_pred_lr) * 100,
    accuracy_score(y_test, y_pred_nb) * 100,
    accuracy_score(y_test, y_pred_dt) * 100,
    accuracy_score(y_test, y_pred_rf) * 100,
    accuracy_score(y_test, y_pred_svm) * 100
]


colors = ["red", "green", "blue", "orange", "yellow"]


plt.bar(models, accuracies, color=colors)


for i, v in enumerate(accuracies):
    plt.text(i, v + 0.5, f"{v:.2f}", ha='center', fontsize=10)

plt.xticks(rotation=20)
plt.xlabel("Models")
plt.ylabel("Accuracy (%)")
plt.title("Model Accuracy Comparison")

plt.show()

# %%
## Summary

# %%
result = pd.DataFrame(list(model_scores.items()), columns=["Model", "Accuracy"])


best_model = result.loc[result["Accuracy"].idxmax()]


second_best = result.sort_values(by="Accuracy", ascending=False).iloc[1]

print("\nSummary:")
print(f"- {best_model['Model']} gave the best accuracy ({best_model['Accuracy']:.2f}%).")
print("- Features like Sulfate and Solids are likely influential based on Random Forest feature importance.")
print(f"- {second_best['Model']} also performed decently.")
# Out:
# Summary:
# - Decision Tree gave the best accuracy (85.69%).
# - Features like Sulfate and Solids are likely influential based on Random Forest feature importance.
# - Random Forest also performed decently.
